# %% [markdown]
# <a href="https://colab.research.google.com/github/bmckimmy/neural-network-challenge-1/blob/main/student_loans_with_deep_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Student Loan Risk with Deep Learning

# %%
# Imports
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from pathlib import Path

# %% [markdown]
# ---
#
# ## Prepare the data to be used on a neural network model

# %% [markdown]
# ### Step 1: Read the `student-loans.csv` file into a Pandas DataFrame. Review the DataFrame, looking for columns that could eventually define your features and target variables.

# %%
# Read the csv into a Pandas DataFrame
file_path = "https://static.bc-edx.com/ai/ail-v-1-0/m18/lms/datasets/student-loans.csv"
loans_df = pd.read_csv(file_path)

# Review the DataFrame
loans_df.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# ...

# %%
# Review the data types associated with the columns
loans_df.dtypes
# Out:
# payment_history           float64
# location_parameter        float64
# stem_degree_score         float64
# gpa_ranking               float64
# alumni_success            float64
# study_major_code          float64
# time_to_completion        float64
# finance_workshop_score    float64
# cohort_ranking            float64
# total_loan_score          float64
# financial_aid_score       float64
# credit_ranking              int64
# dtype: object

# %%
# Check the credit_ranking value counts
loans_df["credit_ranking"].value_counts()
# Out:
# 1    855
# 0    744
# Name: credit_ranking, dtype: int64

# %% [markdown]
# ### Step 2: Using the preprocessed data, create the features (`X`) and target (`y`) datasets. The target dataset should be defined by the preprocessed DataFrame column “credit_ranking”. The remaining columns should define the features dataset.

# %%
# Define the target set y using the credit_ranking column
y = loans_df["credit_ranking"]

# Display a sample of y
y_sample_array = y.head().to_numpy()

y_sample_array
# Out:
# array([0, 0, 0, 1, 0])

# %%
# Define features set X by selecting all columns but credit_ranking
X = loans_df.drop("credit_ranking", axis=1)

# Review the features DataFrame
X_sample = X.head()

X_sample
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# ...

# %% [markdown]
# ### Step 3: Split the features and target sets into training and testing datasets.

# %%
# Split the preprocessed data into a training and testing dataset
# Assign the function a random_state equal to 1
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# ((1279, 11), (320, 11), (1279,), (320,))

# %% [markdown]
# ### Step 4: Use scikit-learn's `StandardScaler` to scale the features data.

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the scaler to the features training dataset
scaler.fit(X_train)

# Fit the scaler to the features training dataset
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

X_train_scaled[:5]
# Out:
# array([[-0.73307913,  0.6648928 , -1.25704443, -0.3204585 , -0.45362151,
#         -0.74240736, -0.6455073 ,  0.24000129,  0.98846046,  0.0630946 ,
#         -0.87223395],
#        [ 1.06774091, -0.62346154,  1.52314768,  0.60886277, -0.36954631,
#         -1.12518952, -1.11200285,  0.18789883, -1.7535127 , -0.17390392,
#         -0.77978452],
#        [-1.74604041, -1.07158479, -1.35814232, -0.53491726, -0.78992229,
#          1.07580793,  0.53628144, -2.67773653,  2.32756363,  0.77409018,
#          3.28799021],
#        [-0.62052788,  0.49684658, -1.05484864, -0.0345135 , -0.20139592,
#          0.11885252,  1.18937522,  0.37546769,  1.24352773, -0.76640023,
#         -0.6873351 ],
#        [-0.50797663,  0.60887739, -1.00429969, -0.53491726,  0.26101766,
#         -0.74240736, -0.7077067 , -0.33312578, -0.09557544, -0.47015208,
#         -0.77978452]])

# %% [markdown]
# ---
#
# ## Compile and Evaluate a Model Using a Neural Network

# %% [markdown]
# ### Step 1: Create a deep neural network by assigning the number of input features, the number of layers, and the number of neurons on each layer using Tensorflow’s Keras.
#
# > **Hint** You can start with a two-layer deep neural network model that uses the `relu` activation function for both layers.

# %%
# Define the the number of inputs (features) to the model
num_features = X_train.shape[1]

# Review the number of features
print(num_features)
# Out:
# 11

# %%
# Define the number of hidden nodes for the first hidden layer
hidden_nodes_layer1 = 6

# Define the number of hidden nodes for the second hidden layer
hidden_nodes_layer2 = 3

# Define the number of neurons in the output layer
output_neurons = 1

# %%
# Create the Sequential model instance
model = Sequential()

# Add the first hidden layer
model.add(Dense(units=hidden_nodes_layer1, input_dim=num_features, activation='relu'))

# Add the second hidden layer
model.add(Dense(units=hidden_nodes_layer2, activation='relu'))

# Add the output layer to the model specifying the number of output neurons and activation function
model.add(Dense(units=output_neurons, activation='sigmoid'))

# %%
# Display the Sequential model summary
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_18 (Dense)            (None, 6)                 72
#
#  dense_19 (Dense)            (None, 3)                 21
#
#  dense_20 (Dense)            (None, 1)                 4
#
# ...
# Total params: 97 (388.00 Byte)
# Trainable params: 97 (388.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Step 2: Compile and fit the model using the `binary_crossentropy` loss function, the `adam` optimizer, and the `accuracy` evaluation metric.

# %%
# Compile the Sequential model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
# Fit the model using 50 epochs and the training data
history = model.fit(X_train_scaled,
                    y_train,
                    epochs=50,
                    batch_size=34,
                    verbose=1)
# Out:
# Epoch 1/50
# 38/38 [==============================] - 1s 2ms/step - loss: 0.7820 - accuracy: 0.5512
# Epoch 2/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6991 - accuracy: 0.5731
# Epoch 3/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6550 - accuracy: 0.6145
# Epoch 4/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6255 - accuracy: 0.6560
# Epoch 5/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6042 - accuracy: 0.6747
# Epoch 6/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5871 - accuracy: 0.6880
# Epoch 7/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5745 - accuracy: 0.6943
# Epoch 8/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5644 - accuracy: 0.6974
# Epoch 9/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5574 - accuracy: 0.7037
# Epoch 10/50
# ...

# %% [markdown]
# ### Step 3: Evaluate the model using the test data to determine the model’s loss and accuracy.

# %%
from sklearn.model_selection import train_test_split
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
# Assuming loans_df is your complete dataset and 'credit_ranking' is the column you want to predict
X = loans_df.drop(columns=['credit_ranking'])  # Features
y = loans_df['credit_ranking']  # Target

# Split the data ensuring the test set has 400 samples
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=400, random_state=1)

# After splitting, scale your features (if needed) then evaluate the model
# Assuming 'scaler' is a previously fitted StandardScaler object
X_test_scaled = scaler.transform(X_test)

# Display the model loss and accuracy results
# Now, evaluate the model using the full X_test_scaled and y_test arrays
results = loaded_model.evaluate(X_test_scaled, y_test, batch_size=32, verbose=1)
print(f"Loss: {results[0]}, Accuracy: {results[1]}")
# Out:
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5128 - accuracy: 0.7300
# Loss: 0.5128020644187927, Accuracy: 0.7300000190734863

# %% [markdown]
# ### Step 4: Save and export your model to a keras file, and name the file `student_loans.keras`.

# %%
# Set the model's file path
file_path = 'student_loans.keras'

# Export your model to a keras file
model.save(file_path)

# %% [markdown]
# ---
# ## Predict Loan Repayment Success by Using your Neural Network Model

# %% [markdown]
# ### Step 1: Reload your saved model.

# %%
from tensorflow.keras.models import load_model

# Set the model's file path
model_file_path = 'student_loans.keras'

# Load the model to a new object
loaded_model = load_model(model_file_path)

# %% [markdown]
# ### Step 2: Make predictions on the testing data and save the predictions to a DataFrame.

# %%
# Make predictions with the test data
number_of_samples = X_test_scaled.shape[0]
batch_size = number_of_samples // 13
if number_of_samples % 13 != 0:
    batch_size += 1
predictions = loaded_model.predict(X_test_scaled, batch_size=batch_size, verbose=1)

# Display a sample of the predictions
predictions[:5]
# Out:
# 13/13 [==============================] - 0s 1ms/step
# array([[0.2790959 ],
#        [0.32124048],
#        [0.7644584 ],
#        [0.75723785],
#        [0.9782102 ]], dtype=float32)

# %%
# Save the predictions to a DataFrame and round the predictions to binary results
# Load your trained model
loaded_model = load_model('student_loans.keras')

# Assuming X_test_scaled is a pandas DataFrame and the last column has been correctly processed
# Ensure that X_test_scaled has the same number of feature columns as expected by the model
# (in this case, 11)

# Check if X_test_scaled is a DataFrame and convert it to a NumPy array if needed
if isinstance(X_test_scaled, pd.DataFrame):
    X_test_features = X_test_scaled.values
else:
    X_test_features = X_test_scaled

# The error suggests that one feature column is missing, hence we ensure we have all 11 feature columns
assert X_test_features.shape[1] == 11, "The input features must have 11 columns."

# Continue with the rest of your code for thresholding and converting to DataFrame
threshold = 0.5  # Typical threshold for binary classification

# Convert predictions to binary outcomes using the chosen threshold
binary_predictions = (predictions.ravel() > threshold).astype(float)

# Create a DataFrame to save the binary predictions
predictions_df = pd.DataFrame(binary_predictions, columns=['predictions'])

# Display the DataFrame
predictions_df
# Out:
#      predictions
# 0            0.0
# 1            0.0
# 2            1.0
# 3            1.0
# 4            1.0
# ..           ...
# 395          1.0
# 396          0.0
# 397          1.0
# 398          0.0
# 399          1.0
#
# [400 rows x 1 columns]

# %% [markdown]
# ### Step 4: Display a classification report with the y test data and predictions

# %%
# Now let's print the classification report using the true labels (y_test) and the binary predictions
report = classification_report(y_test, binary_predictions)

# Print the classification report
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.77      0.73       188
#            1       0.77      0.69      0.73       212
#
#     accuracy                           0.73       400
#    macro avg       0.73      0.73      0.73       400
# weighted avg       0.73      0.73      0.73       400

# %% [markdown]
# ---
# ## Discuss creating a recommendation system for student loans

# %% [markdown]
# Briefly answer the following questions in the space provided:
#
# 1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.
#
# 2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.
#
# 3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.

# %% [markdown]
# **1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.**
#
# 1. Data Collection for Recommendation System:
# To develop a student loan recommendation system, you would need to gather data that reflect both the characteristics of the loans and the financial and educational profiles of the students. Relevant data might include:
#
# Student Information: GPA, major, school, expected graduation date, part-time or full-time status, and post-graduation income projections.
# Financial Data: Previous loan amounts, scholarships, work-study participation, family contribution, and credit score.
# Loan Terms: Interest rates, repayment periods, loan amounts, federal vs. private loans, grace periods, and deferment options.
#
# This data is relevant as it allows for personalized recommendations. The academic and financial information help in estimating the student's capacity to repay the loan, while the loan terms are critical in matching with the student's financial needs and repayment ability.
#
# **2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.**
#
# 2. Choice of Filtering Method:
# The model would likely employ a content-based filtering approach because the recommendation is highly personal and based on the specific attributes of each student's financial need and capacity. Content-based filtering can utilize the detailed profile of the student's financial situation and academic trajectory to match them with loan options that have compatible terms and conditions. The suitability of this approach lies in its ability to factor in numerous characteristics that are unique to each student, such as anticipated income, which is crucial for recommending a loan with affordable repayments.
#
# **3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.**
#
# 3. Real-world Challenges:
# Two significant challenges include:
#
# Data Privacy and Security: Students' financial data is sensitive. Ensuring data protection and privacy is crucial, requiring robust security measures to prevent breaches that could lead to identity theft or financial fraud.
#
# Regulatory Compliance: Student loans are heavily regulated. A recommendation system must comply with all laws and regulations, including fair lending practices and transparent disclosure of loan terms, to avoid legal issues and ensure that recommendations are ethical and fair.
#
# These challenges are particularly relevant to a student loan recommendation system due to the sensitive nature of the personal and financial data involved, which if misused, could have serious legal and personal repercussions for the students.
